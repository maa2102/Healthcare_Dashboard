# %% [markdown]
# # 1.0 Data Gathering

# %%
import pandas as pd

# %%
df = pd.read_excel("IJN Risk Score  2018 - 2022.xlsx")
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
df.head()
# Out:
# Rows: 10733
# Columns: 201
#    ID    PCCardiacProc        DOB     Sex RaceName ReligionName MaritalName  \
# 0   1      Valve alone 1966-02-21    MALE    Malay        Islam     Married
# 1   2  Valve and Other 1942-05-08  FEMALE    Malay        Islam     Married
# 2   3            other 1990-06-17  FEMALE    Malay        Islam      Single
# 3   4      Valve alone 1976-11-27    MALE    Malay        Islam      Single
# 4   5      Valve alone 1989-01-03  FEMALE  Chinese     Buddhism     Married
#
#              StateName CitizenName ResidentialName  ... CurrMed10  PFE  PIM  \
# 0             Selangor    Malaysia       Malaysian  ...       NaN  YES  YES
# 1      Negeri Sembilan    Malaysia       Malaysian  ...       NaN  YES  YES
# 2               Perlis    Malaysia       Malaysian  ...       NaN   NO   NO
# 3                Perak    Malaysia       Malaysian  ...       NaN   NO   NO
# 4  Wilayah Persekutuan    Malaysia       Malaysian  ...       NaN  YES   NO
#
#   DateInOperation  Consultant  Completeness Euroscore EuroscoreII  \
# 0      2019-04-29           F      COMPLETE         5        2.88
# 1      2019-10-17           A      COMPLETE         9        6.16
# 2      2020-11-27           G      COMPLETE         3        0.62
# 3      2018-03-06           F      COMPLETE         5        1.74
# 4      2021-01-13           I      COMPLETE         3        0.62
#
#   BernParsonnet PTStatusDischarge
# 0            10             Alive
# 1            27             Alive
# 2             1             Alive
# 3            12             Alive
# 4             1             Alive
#
# [5 rows x 201 columns]

# %% [markdown]
# # 2.0 Data Examination

# %%
list(df.columns)
# Out:
# ['ID',
#  'PCCardiacProc',
#  'DOB',
#  'Sex',
#  'RaceName',
#  'ReligionName',
#  'MaritalName',
#  'StateName',
#  'CitizenName',
#  'ResidentialName',
#  'Postcode',
#  'DeceasedDateTime',
#  'AdmissionDate',
#  'DischargeDate',
#  'AgeInMonth',
#  'AgeInYear',
#  'GLTypeName',
#  'RA_ValveRepair',
#  'RA_ValveReplacement',
#  'RA_CABG',
#  'RA_OthersSurgery',
#  'RA_NonSurgery',
#  'Orthopnea',
#  'Paroxysmal',
#  'SymptomStatus',
#  'PMHNone',
#  'AnginaStatusPresurgery',
#  'UnstableAngina',
#  'DyspneaStatusPresurgery',
#  'SymptomNone',
#  'ShortofBreath',
#  'ChestPain',
#  'Fatigue',
#  'Palpilation',
#  'sFever',
#  'Cough',
#  'Hemoptysis',
#  'LostofAppetite',
#  'LostofWeight',
#  'LostofConsciousness',
#  'SymptomOthers',
#  'PreviousMI',
#  'IntervalSurgeryLastMI',
#  'PreviousPCI',
#  'FailedInterventionPCI',
#  'PreviousCardiacNone',
#  'PreviousCardiacCABG',
#  'PreviousCardiacValve',
#  'PreviousCardiacCongenital',
#  'PreviousCardiacOther',
#  'PreviousCardiacAscAorta',
#  'PreviousCardiacDescAorta',
#  'PreviousCardiacOtherThorac',
#  'PreviousCardiacCarotid',
#  'PreviousCardiacOtherPeri',
#  'OthersPreviousCardiac',
#  'PulmonaryNone',
#  'PulmonaryCOPD',
#  'PulmonaryAsthma',
#  'PulmonaryTB',
#  'PulmonaryLong',
#  'NoHistofNeurological',
#  'TIAorRIND',
#  'CVAwithFullRec',
#  'CVAwithResDef',
#  'PoorMobility',
#  'GastroenterologyNone',
#  'GastroenterologyGas',
#  'GastroenterologyPUD',
#  'GastroenterologyIBD',
#  'GastroenterologyUN',
#  'GastroenterologyOt',
#  'RFCADNone',
#  'RFAcquisitionofDiabetic',
#  'DMNot',
#  'DMDiet',
#  'DMOral',
#  'DMInsulin',
#  'RFAcquisitionofSmoking',
#  'RFAcquisitionofHypertension',
#  'RFAcquisitionofHyperchloles',
#  'RFAcquisitionofAlcohol',
#  'RFAcquisitionofOthers',
#  'AddMedHistRFRenalDis',
#  'NoRenalDisease',
#  'FunctionalTransplant',
#  'CreatineMore2mg',
#  'DialysisAcuteRenal',
#  'ChronicKidneyDisease',
#  'DialysisCRF',
#  'ArteriopathNone',
#  'ArteriopathClaudication',
#  'ArteriopathAmputation',
#  'ArteriopathIntervention',
#  'ArteriopathCarotid',
#  'ArteriopathAortic',
#  'PlannedOperation',
#  'CABGTimeValveSurgery',
#  'PlannedOperationAorta',
#  'SinusRhythm',
#  'AtrialFibrilation',
#  'CompleteHeartBlockPaced',
#  'FamilyHistory',
#  'ActiveEndocarditis',
#  'Alergic',
#  'PreopCoros',
#  'PreopCorosFinding',
#  'ClinicalPOS',
#  'PreopVentilation',
#  'PreOpCardiacMassage',
#  'PreOpAcuteRenalFailure',
#  'PreopInotropesIABP',
#  'VT_VF',
#  'OtherAbnormalRhythm',
#  'urgency',
#  'PreopCretinine',
#  'SurgeryNone',
#  'SurgeryAortic',
#  'SurgeryMitral',
#  'SurgeryTricuspid',
#  'SurgeryPulmonary',
#  'PostInfarct',
#  'LVAneurymectomy',
#  'RedoOperation',
#  'MaritalStatus',
#  'Working',
#  'CLExtentofCoronary',
#  'CLLeftmainsteam',
#  'CLEjectionFraction',
#  'CLEjectionSystolic',
#  'PateintHeightcm',
#  'PatientWeightkg',
#  'BMI',
#  'PC_Cramp',
#  'PC_Throb',
#  'PC_Sharp',
#  'PC_Heavy',
#  'PC_Tender',
#  'Freq_Constant',
#  'Freq_Inter',
#  'Agg_Move',
#  'Agg_Position',
#  'Relief_Med',
#  'Relief_NonMed',
#  'MP_ContNormal',
#  'MP_DisPlatlet',
#  'MP_DisOral',
#  'PA_Normal',
#  'PA_Anxious',
#  'PA_Depress',
#  'PA_Illness',
#  'PA_IllnessSpecify',
#  'PA_Others',
#  'PA_OthersSpecify',
#  'Invest_Lab',
#  'Invest_Blood',
#  'Invest_BloodCABG',
#  'Invest_BloodRedo',
#  'Invest_BloodAortic',
#  'Invest_BloodOthers',
#  'Invest_BloodOthersSpecify',
#  'Invest_Chest',
#  'Invest_ECG',
#  'Invest_2DEcho',
#  'Invest_Lung',
#  'Invest_Others',
#  'Invest_OthersSpecify',
#  'FO_Healthy',
#  'FO_Diabetes',
#  'FO_Dialysis',
#  'FO_Fluid',
#  'FO_FluidVal',
#  'FO_Others',
#  'FO_OthersSpecify',
#  'ProbPatient1',
#  'ProbPatient2',
#  'ProbPatient3',
#  'ProbPatient4',
#  'CarePlan1',
#  'CarePlan2',
#  'CarePlan3',
#  'CarePlan4',
#  'CurrMed1',
#  'CurrMed2',
#  'CurrMed3',
#  'CurrMed4',
#  'CurrMed5',
#  'CurrMed6',
#  'CurrMed7',
#  'CurrMed8',
#  'CurrMed9',
#  'CurrMed10',
#  'PFE',
#  'PIM',
#  'DateInOperation',
#  'Consultant',
#  'Completeness',
#  'Euroscore',
#  'EuroscoreII',
#  'BernParsonnet',
#  'PTStatusDischarge']

# %%
duplicates = df['ID'].duplicated()
print("Number of duplicated rows unique id:", duplicates.sum())
# Out:
# Number of duplicated rows unique id: 0

# %%
def categorize_columns(df):
    column_types = {}
    type_counts = {'Boolean': 0, 'Unique ID/Numeric': 0,'Textual/Date/Reference Number': 0, 'Categorical': 0}

    for column in df.columns:
        unique_values = df[column].nunique()
        data_type = df[column].dtype

        if unique_values < 3:
            category = 'Boolean'
        elif pd.api.types.is_numeric_dtype(data_type):
            category = 'Unique ID/Numeric'
        elif unique_values > 30:
            category = 'Textual/Date/Reference Number'
        else:
            category = 'Categorical'

        column_types[column] = category
        type_counts[category] += 1

    return column_types, type_counts

# %%
column_categories, type_counts = categorize_columns(df)
print("Column Categories:", column_categories)
print("Total Columns for Each Data Type:")
for category, count in type_counts.items():
    print(f"{category}: {count}")
# Out:
# Column Categories: {'ID': 'Unique ID/Numeric', 'PCCardiacProc': 'Categorical', 'DOB': 'Textual/Date/Reference Number', 'Sex': 'Boolean', 'RaceName': 'Categorical', 'ReligionName': 'Categorical', 'MaritalName': 'Categorical', 'StateName': 'Categorical', 'CitizenName': 'Textual/Date/Reference Number', 'ResidentialName': 'Categorical', 'Postcode': 'Textual/Date/Reference Number', 'DeceasedDateTime': 'Textual/Date/Reference Number', 'AdmissionDate': 'Textual/Date/Reference Number', 'DischargeDate': 'Textual/Date/Reference Number', 'AgeInMonth': 'Unique ID/Numeric', 'AgeInYear': 'Unique ID/Numeric', 'GLTypeName': 'Textual/Date/Reference Number', 'RA_ValveRepair': 'Boolean', 'RA_ValveReplacement': 'Boolean', 'RA_CABG': 'Boolean', 'RA_OthersSurgery': 'Boolean', 'RA_NonSurgery': 'Boolean', 'Orthopnea': 'Categorical', 'Paroxysmal': 'Categorical', 'SymptomStatus': 'Boolean', 'PMHNone': 'Boolean', 'AnginaStatusPresurgery': 'Categorical', 'UnstableAngina': 'Categorical', 'DyspneaStatusPresurgery': 'Categorical', 'SymptomNone': 'Boolean', 'ShortofBreath': 'Boolean', 'ChestPain': 'Boolean', 'Fatigue': 'Boolean', 'Palpilation': 'Boolean', 'sFever': 'Boolean', 'Cough': 'Boolean', 'Hemoptysis': 'Boolean', 'LostofAppetite': 'Boolean', 'LostofWeight': 'Boolean', 'LostofConsciousness': 'Boolean', 'SymptomOthers': 'Textual/Date/Reference Number', 'PreviousMI': 'Categorical', 'IntervalSurgeryLastMI': 'Categorical', 'PreviousPCI': 'Categorical', 'FailedInterventionPCI': 'Categorical', 'PreviousCardiacNone': 'Boolean', 'PreviousCardiacCABG': 'Boolean', 'PreviousCardiacValve': 'Boolean', 'PreviousCardiacCongenital': 'Boolean', 'PreviousCardiacOther': 'Boolean', 'PreviousCardiacAscAorta': 'Boolean', 'PreviousCardiacDescAorta': 'Boolean', 'PreviousCardiacOtherThorac': 'Boolean', 'PreviousCardiacCarotid': 'Boolean', 'PreviousCardiacOtherPeri': 'Boolean', 'OthersPreviousCardiac': 'Boolean', 'PulmonaryNone': 'Boolean', 'PulmonaryCOPD': 'Boolean', 'PulmonaryAsthma': 'Boolean', 'PulmonaryTB': 'Boolean', 'PulmonaryLong': 'Boolean', 'NoHistofNeurological': 'Boolean', 'TIAorRIND': 'Boolean', 'CVAwithFullRec': 'Boolean', 'CVAwithResDef': 'Boolean', 'PoorMobility': 'Categorical', 'GastroenterologyNone': 'Boolean', 'GastroenterologyGas': 'Boolean', 'GastroenterologyPUD': 'Boolean', 'GastroenterologyIBD': 'Boolean', 'GastroenterologyUN': 'Boolean', 'GastroenterologyOt': 'Boolean', 'RFCADNone': 'Boolean', 'RFAcquisitionofDiabetic': 'Categorical', 'DMNot': 'Boolean', 'DMDiet': 'Boolean', 'DMOral': 'Boolean', 'DMInsulin': 'Boolean', 'RFAcquisitionofSmoking': 'Categorical', 'RFAcquisitionofHypertension': 'Categorical', 'RFAcquisitionofHyperchloles': 'Categorical', 'RFAcquisitionofAlcohol': 'Categorical', 'RFAcquisitionofOthers': 'Boolean', 'AddMedHistRFRenalDis': 'Boolean', 'NoRenalDisease': 'Boolean', 'FunctionalTransplant': 'Boolean', 'CreatineMore2mg': 'Boolean', 'DialysisAcuteRenal': 'Boolean', 'ChronicKidneyDisease': 'Boolean', 'DialysisCRF': 'Boolean', 'ArteriopathNone': 'Boolean', 'ArteriopathClaudication': 'Boolean', 'ArteriopathAmputation': 'Boolean', 'ArteriopathIntervention': 'Boolean', 'ArteriopathCarotid': 'Boolean', 'ArteriopathAortic': 'Boolean', 'PlannedOperation': 'Categorical', 'CABGTimeValveSurgery': 'Categorical', 'PlannedOperationAorta': 'Boolean', 'SinusRhythm': 'Boolean', 'AtrialFibrilation': 'Boolean', 'CompleteHeartBlockPaced': 'Boolean', 'FamilyHistory': 'Categorical', 'ActiveEndocarditis': 'Categorical', 'Alergic': 'Categorical', 'PreopCoros': 'Categorical', 'PreopCorosFinding': 'Categorical', 'ClinicalPOS': 'Categorical', 'PreopVentilation': 'Boolean', 'PreOpCardiacMassage': 'Boolean', 'PreOpAcuteRenalFailure': 'Boolean', 'PreopInotropesIABP': 'Boolean', 'VT_VF': 'Boolean', 'OtherAbnormalRhythm': 'Boolean', 'urgency': 'Categorical', 'PreopCretinine': 'Textual/Date/Reference Number', 'SurgeryNone': 'Boolean', 'SurgeryAortic': 'Boolean', 'SurgeryMitral': 'Boolean', 'SurgeryTricuspid': 'Boolean', 'SurgeryPulmonary': 'Boolean', 'PostInfarct': 'C ...
# Total Columns for Each Data Type:
# Boolean: 119
# Unique ID/Numeric: 7
# Textual/Date/Reference Number: 31
# Categorical: 44

# %%
def unique_values(dataframe):
    for column in dataframe.columns:
        unique_values = dataframe[column].unique()
        unique_values_top = dataframe[column].unique()[:5]
        num_unique_values = len(unique_values)

        print(f"Column: {column}, Number of Unique Values: {num_unique_values}")

        print("Unique Values:")
        print(unique_values_top)
        print("---------------------------")

# %%
unique_values(df)
# Out:
# Column: ID, Number of Unique Values: 10733
# Unique Values:
# [1 2 3 4 5]
# ---------------------------
# Column: PCCardiacProc, Number of Unique Values: 7
# Unique Values:
# ['Valve alone' 'Valve and Other' 'other' 'CABG alone' 'CABG and Valve']
# ---------------------------
# Column: DOB, Number of Unique Values: 7402
# Unique Values:
# ['1966-02-21T00:00:00.000000000' '1942-05-08T00:00:00.000000000'
#  '1990-06-17T00:00:00.000000000' '1976-11-27T00:00:00.000000000'
#  '1989-01-03T00:00:00.000000000']
# ---------------------------
# Column: Sex, Number of Unique Values: 2
# Unique Values:
# ['MALE' 'FEMALE']
# ---------------------------
# Column: RaceName, Number of Unique Values: 26
# Unique Values:
# ['Malay' 'Chinese' 'Indian' 'Punjabi' 'Others']
# ---------------------------
# Column: ReligionName, Number of Unique Values: 7
# Unique Values:
# ['Islam' 'Buddhism' 'Hindu' 'Christian' 'Sikh']
# ---------------------------
# Column: MaritalName, Number of Unique Values: 7
# Unique Values:
# ['Married' 'Single' 'Widower' 'Unknown' 'Divorced']
# ---------------------------
# Column: StateName, Number of Unique Values: 27
# Unique Values:
# ['Selangor' 'Negeri Sembilan' 'Perlis' 'Perak' 'Wilayah Persekutuan']
# ---------------------------
# Column: CitizenName, Number of Unique Values: 32
# Unique Values:
# ['Malaysia' 'Egypt' 'Indonesia' 'Singapore' 'Sri Lanka']
# ---------------------------
# Column: ResidentialName, Number of Unique Values: 5
# Unique Values:
# ['Malaysian' 'Permanent Resident' 'Foreigner - Medical Tourism'
#  'Foreigner - Expatriate' 'Foreigner - Visitor']
# ---------------------------
# Column: Postcode, Number of Unique Values: 777
# Unique Values:
# [43950 72000 2600 32040 51000]
# ---------------------------
# Column: DeceasedDateTime, Number of Unique Values: 737
# Unique Values:
# ['0/0/0 00:00:00' datetime.datetime(2022, 12, 21, 21, 10)
#  datetime.datetime(2021, 9, 29, 8, 35)
#  datetime.datetime(2018, 3, 14, 18, 0)
#  datetime.datetime(2019, 5, 19, 15, 30)]
# ---------------------------
# Column: AdmissionDate, Number of Unique Values: 10650
# Unique Values:
# ['2019-04-13T10:48:00.000000000' '2019-10-09T07:38:00.000000000'
#  '2020-11-23T10:31:00.000000000' '2018-03-03T08:38:00.000000000'
#  '2021-01-10T10:42:00.000000000']
# ---------------------------
# Column: DischargeDate, Number of Unique Values: 10071
# Unique Values:
# ['2019-05-05T15:40:00.000000000' '2019-10-26T17:08:00.000000000'
#  '2020-12-16T19:53:00.000000000' '2018-03-13T18:50:00.000000000'
#  '2021-01-19T17:24:00.000000000']
# ---------------------------
# Column: AgeInMonth, Number of Unique Values: 767
# Unique Values:
# [636 929 365 495 384]
# ---------------------------
# Column: AgeInYear, Number of Unique Values: 70
# Unique Values:
# [53 77 30 41 32]
# ---------------------------
# Column: GLTypeName, Number of Unique Values: 42
# Unique Values:
# ['GOVT - Dependent' 'PENS - Dependent' 'Govt Sponsored Patient'
#  'GOVT - Staff' 'Private Paying Ind.']
# ---------------------------
# Column: RA_ValveRepair, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: RA_ValveReplacement, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: RA_CABG, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: RA_OthersSurgery, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: RA_NonSurgery, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Orthopnea, Number of Unique Values: 4
# Unique Values:
# ['NO' 'YES' nan 'UNKNOWN']
# ---------------------------
# Column: Paroxysmal, Number of Unique Values: 4
# Unique Values:
# ['YES' 'NO' nan 'UNKNOWN']
# ---------------------------
# Column: SymptomStatus, Number of Unique Values: 3
# Unique Values:
# ['Stable' 'Unstable / recent deterioration' nan]
# ---------------------------
# Column: PMHNone, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: AnginaStatusPresurgery, Number of Unique Values: 7
# Unique Values:
# ['CSS (NO SIGN)' 'CSS1' 'CSS2' nan 'CSS4']
# ---------------------------
# Column: UnstableAngina, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'YES' 'UNKNOWN']
# ---------------------------
# Column: DyspneaStatusPresurgery, Number of Unique Values: 6
# Unique Values:
# ['NYHA II' 'NYHA I' 'NYHA III' nan 'NYHA IV']
# ---------------------------
# Column: SymptomNone, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ShortofBreath, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: ChestPain, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Fatigue, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Palpilation, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: sFever, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Cough, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Hemoptysis, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: LostofAppetite, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: LostofWeight, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: LostofConsciousness, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: SymptomOthers, Number of Unique Values: 126
# Unique Values:
# [nan 'dizziness' 'reduce effort tolerance' 'worsening' 'giddiness']
# ---------------------------
# Column: PreviousMI, Number of Unique Values: 5
# Unique Values:
# ['none' 'two / more' 'one' nan 'Unknown']
# ---------------------------
# Column: IntervalSurgeryLastMI, Number of Unique Values: 9
# Unique Values:
# ['No Previous MI' 'MI 22-90 days' 'MI > 90 days' 'MI 1 - 7 Days'
#  'MI 8-21 days']
# ---------------------------
# Column: PreviousPCI, Number of Unique Values: 6
# Unique Values:
# ['No PCI' nan 'PCI > 24 Hours Before Surgery, Previous Admission'
#  'PCI > 24 Hours Before Surgery, Same Admission' 'Unknown']
# ---------------------------
# Column: FailedInterventionPCI, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'YES' 'UNKNOWN']
# ---------------------------
# Column: PreviousCardiacNone, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacCABG, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacValve, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: PreviousCardiacCongenital, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacOther, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacAscAorta, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacDescAorta, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacOtherThorac, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacCarotid, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PreviousCardiacOtherPeri, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: OthersPreviousCardiac, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: PulmonaryNone, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: PulmonaryCOPD, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PulmonaryAsthma, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PulmonaryTB, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PulmonaryLong, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: NoHistofNeurological, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: TIAorRIND, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: CVAwithFullRec, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: CVAwithResDef, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PoorMobility, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'YES' 'UNKNOWN']
# ---------------------------
# Column: GastroenterologyNone, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: GastroenterologyGas, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: GastroenterologyPUD, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: GastroenterologyIBD, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: GastroenterologyUN, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: GastroenterologyOt, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: RFCADNone, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: RFAcquisitionofDiabetic, Number of Unique Values: 4
# Unique Values:
# ['NO' 'YES' nan 'UNKNOWN']
# ---------------------------
# Column: DMNot, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: DMDiet, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: DMOral, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: DMInsulin, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: RFAcquisitionofSmoking, Number of Unique Values: 5
# Unique Values:
# ['Never' 'Unknown' 'Ex-Smoker' nan 'Current Smoker']
# ---------------------------
# Column: RFAcquisitionofHypertension, Number of Unique Values: 4
# Unique Values:
# ['NO' 'YES' nan 'UNKNOWN']
# ---------------------------
# Column: RFAcquisitionofHyperchloles, Number of Unique Values: 4
# Unique Values:
# ['NO' 'YES' nan 'UNKNOWN']
# ---------------------------
# Column: RFAcquisitionofAlcohol, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'UNKNOWN' 'YES']
# ---------------------------
# Column: RFAcquisitionofOthers, Number of Unique Values: 1
# Unique Values:
# [nan]
# ---------------------------
# Column: AddMedHistRFRenalDis, Number of Unique Values: 1
# Unique Values:
# [nan]
# ---------------------------
# Column: NoRenalDisease, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: FunctionalTransplant, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: CreatineMore2mg, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: DialysisAcuteRenal, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ChronicKidneyDisease, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: DialysisCRF, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ArteriopathNone, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: ArteriopathClaudication, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ArteriopathAmputation, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ArteriopathIntervention, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ArteriopathCarotid, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: ArteriopathAortic, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PlannedOperation, Number of Unique Values: 6
# Unique Values:
# ['Two procedures' 'Single procedure, non CABG' nan 'Three procedures'
#  'Isolated CABG']
# ---------------------------
# Column: CABGTimeValveSurgery, Number of Unique Values: 4
# Unique Values:
# ['NO' 'UNKNOWN' nan 'YES']
# ---------------------------
# Column: PlannedOperationAorta, Number of Unique Values: 3
# Unique Values:
# ['NO' nan 'YES']
# ---------------------------
# Column: SinusRhythm, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: AtrialFibrilation, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: CompleteHeartBlockPaced, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: FamilyHistory, Number of Unique Values: 4
# Unique Values:
# ['YES' 'NO' nan 'UNKNOWN']
# ---------------------------
# Column: ActiveEndocarditis, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'UNKNOWN' 'YES']
# ---------------------------
# Column: Alergic, Number of Unique Values: 4
# Unique Values:
# ['NO' 'YES' nan 'UNKNOWN']
# ---------------------------
# Column: PreopCoros, Number of Unique Values: 4
# Unique Values:
# ['YES' 'NO' nan 'UNKNOWN']
# ---------------------------
# Column: PreopCorosFinding, Number of Unique Values: 7
# Unique Values:
# ['Normal' 'None' nan 'Triple' 'Single']
# ---------------------------
# Column: ClinicalPOS, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'YES' 'UNKNOWN']
# ---------------------------
# Column: PreopVentilation, Number of Unique Values: 3
# Unique Values:
# ['NO' nan 'YES']
# ---------------------------
# Column: PreOpCardiacMassage, Number of Unique Values: 3
# Unique Values:
# ['NO' nan 'YES']
# ---------------------------
# Column: PreOpAcuteRenalFailure, Number of Unique Values: 3
# Unique Values:
# ['NO' nan 'YES']
# ---------------------------
# Column: PreopInotropesIABP, Number of Unique Values: 3
# Unique Values:
# ['NO' 'YES' nan]
# ---------------------------
# Column: VT_VF, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: OtherAbnormalRhythm, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: urgency, Number of Unique Values: 5
# Unique Values:
# ['Elective' 'Urgent' 'Emergency' 'Salvage' nan]
# ---------------------------
# Column: PreopCretinine, Number of Unique Values: 538
# Unique Values:
# [82 108 41 93 53]
# ---------------------------
# Column: SurgeryNone, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: SurgeryAortic, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: SurgeryMitral, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: SurgeryTricuspid, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: SurgeryPulmonary, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PostInfarct, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'YES' 'UNKNOWN']
# ---------------------------
# Column: LVAneurymectomy, Number of Unique Values: 4
# Unique Values:
# ['NO' nan 'YES' 'UNKNOWN']
# ---------------------------
# Column: RedoOperation, Number of Unique Values: 5
# Unique Values:
# ['First' 'None' 'Second' nan 'Third']
# ---------------------------
# Column: MaritalStatus, Number of Unique Values: 5
# Unique Values:
# ['Married' 'Single' nan 'Widower' 'Divorced']
# ---------------------------
# Column: Working, Number of Unique Values: 4
# Unique Values:
# ['YES' 'NO' nan 'UNKNOWN']
# ---------------------------
# Column: CLExtentofCoronary, Number of Unique Values: 7
# Unique Values:
# ['No vessel with >50% diameter stenosis' 'Not investigated' nan
#  'Three vessel with >50% diameter stenosis'
#  'One vessel with >50% diameter stenosis']
# ---------------------------
# Column: CLLeftmainsteam, Number of Unique Values: 6
# Unique Values:
# [nan 'No LMS disease' 'Not investigated'
#  'LMS disease >50% diameter stenosis'
#  'LMS disease <=50% diameter stenosis']
# ---------------------------
# Column: CLEjectionFraction, Number of Unique Values: 116
# Unique Values:
# [52 58 54 30 77]
# ---------------------------
# Column: CLEjectionSystolic, Number of Unique Values: 5
# Unique Values:
# ['EF: > 50%' 'EF: 21 - 30%' 'EF: 31 - 50%' nan 'EF <= 20%']
# ---------------------------
# Column: PateintHeightcm, Number of Unique Values: 322
# Unique Values:
# [175 145.7 144 168.5 153]
# ---------------------------
# Column: PatientWeightkg, Number of Unique Values: 769
# Unique Values:
# [82.5 57.5 44.2 69.8 40.9]
# ---------------------------
# Column: BMI, Number of Unique Values: 2042
# Unique Values:
# [26.94 27.09 21.32 24.58 17.47]
# ---------------------------
# Column: PC_Cramp, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PC_Throb, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PC_Sharp, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PC_Heavy, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PC_Tender, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Freq_Constant, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Freq_Inter, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Agg_Move, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Agg_Position, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Relief_Med, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Relief_NonMed, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: MP_ContNormal, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: MP_DisPlatlet, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: MP_DisOral, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PA_Normal, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: PA_Anxious, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PA_Depress, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PA_Illness, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PA_IllnessSpecify, Number of Unique Values: 5
# Unique Values:
# [nan 'AGGRESSIVE' 'depression' 'INSOMNIA' 'depression, insomnia']
# ---------------------------
# Column: PA_Others, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: PA_OthersSpecify, Number of Unique Values: 8
# Unique Values:
# [nan 'Intubated' 'Patient intubated, on minimal sedation' 'Unknown '
#  'autism']
# ---------------------------
# Column: Invest_Lab, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_Blood, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_BloodCABG, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Invest_BloodRedo, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_BloodAortic, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Invest_BloodOthers, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Invest_BloodOthersSpecify, Number of Unique Values: 109
# Unique Values:
# [nan 'For Excision of atrial Myxoma + TAP '
#  'for MV + TV repair KIV replacement' '4 unit PC'
#  'GXM 4 PC AND 1 CYCLE DIVC']
# ---------------------------
# Column: Invest_Chest, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_ECG, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_2DEcho, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_Lung, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: Invest_Others, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: Invest_OthersSpecify, Number of Unique Values: 93
# Unique Values:
# [nan 'AP lateral cxr ' 'Covid-19' 'COROS' 'TFT']
# ---------------------------
# Column: FO_Healthy, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: FO_Diabetes, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: FO_Dialysis, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: FO_Fluid, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: FO_FluidVal, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: FO_Others, Number of Unique Values: 2
# Unique Values:
# ['NO' 'YES']
# ---------------------------
# Column: FO_OthersSpecify, Number of Unique Values: 8
# Unique Values:
# [nan 'Maintainence ivd' 'Therapeutic diet- Post Kidney transplant'
#  'diet for gout' 'CKD']
# ---------------------------
# Column: ProbPatient1, Number of Unique Values: 2340
# Unique Values:
# ['s/p DVR (mechanical)' 'RIGHT VENTRICULAR FAILURE' nan 'severe PR'
#  'free flow PR']
# ---------------------------
# Column: ProbPatient2, Number of Unique Values: 1566
# Unique Values:
# [nan 'SEVERE PULMONARY HYPERTENSION' 's/P TOF repair' 'HPT' 'AF']
# ---------------------------
# Column: ProbPatient3, Number of Unique Values: 1235
# Unique Values:
# [nan 'SEVERE MR AND TR'
#  ' Partial epilepsy secondary to  frontal encephalomalacia ' 'AF'
#  'POST MV REPAIR 1996']
# ---------------------------
# Column: ProbPatient4, Number of Unique Values: 914
# Unique Values:
# [nan 'Thalassemia trait' 'BPH' 'SCOLIOSIS' 'ANAEMIA']
# ---------------------------
# Column: CarePlan1, Number of Unique Values: 1761
# Unique Values:
# ['Redo AVR ' 'MITRIAL VALVE REPLACEMENT (BIOPROSTHESIS)' nan
#  'For Pre op assesment' 'AVR']
# ---------------------------
# Column: CarePlan2, Number of Unique Values: 805
# Unique Values:
# ['Pre op COROS' 'TRICUSPID ANNULOPLASTY' nan 'MVR+TVR' 'FOR TVR']
# ---------------------------
# Column: CarePlan3, Number of Unique Values: 232
# Unique Values:
# [nan 'LEFT ATIRIALAPPENDAGE LIGATION' 'FOR MVR+TVR'
#  'FOR PRIMARY TEAM TO REVIEW' 'for primary team to review']
# ---------------------------
# Column: CarePlan4, Number of Unique Values: 52
# Unique Values:
# [nan ' ' 'Preop work up' 'LUNG FUNCTION TEST ' 'RESP PHYSIO']
# ---------------------------
# Column: CurrMed1, Number of Unique Values: 626
# Unique Values:
# ['as ps' 'as per prescription sheet' nan 'as per prescription'
#  'epilicillin']
# ---------------------------
# Column: CurrMed2, Number of Unique Values: 437
# Unique Values:
# [nan 'APT-STOPED' 'ferrous fumarate 5 mg daily'
#  'STOPPED ANTIPLATELET ON 25/9/8' 'STOPPED WARFARIN 27/7/18']
# ---------------------------
# Column: CurrMed3, Number of Unique Values: 112
# Unique Values:
# [nan 'STOP CLEXANE 10/5/19' 'AS PS' 'STOPPED WARFARIN 15/6/19'
#  'PERINDOPRIL 8 MG OD ']
# ---------------------------
# Column: CurrMed4, Number of Unique Values: 96
# Unique Values:
# [nan 'AS PS' 'BISOPROLOL 2.5MG OD ' 'SL GTN/ T.PANTOPRAZOLE  40 MG OD'
#  'bisoprolol 2.5mg od ']
# ---------------------------
# Column: CurrMed5, Number of Unique Values: 78
# Unique Values:
# [nan 'AS PS' 'TRIMETAZIDINE 20MG TDS' 'T.FRUSEMIDE 20 MG  OD' 'as ps']
# ---------------------------
# Column: CurrMed6, Number of Unique Values: 70
# Unique Values:
# [nan 'S/L GTN 1/1 PRN ' 'T.PERINDOPRIL 4 MG OD' 'vasteral 35mg bd '
#  'OMEPRAZOLE']
# ---------------------------
# Column: CurrMed7, Number of Unique Values: 47
# Unique Values:
# [nan 'AS PS' 'SCLEVEMIR 12 UNITS ON' 'fenofibrate 145mg od '
#  'lipitor 20mg on']
# ---------------------------
# Column: CurrMed8, Number of Unique Values: 32
# Unique Values:
# [nan 'AS PS' 'SC NOVORAPID 10 UNITS TDS' 'ezeterol 10mg od '
#  'concor 2.5mg od']
# ---------------------------
# Column: CurrMed9, Number of Unique Values: 21
# Unique Values:
# [nan 'T.ATORVASTATIN 40 MG ON' 's/c novomix 20 unit BD ' 'galvusmet '
#  'S/L GTN 0.5mg PRN']
# ---------------------------
# Column: CurrMed10, Number of Unique Values: 13
# Unique Values:
# [nan 'MDI SEEBRI INHALATION 1 CAP OD' 'januvia 50mg od ' 'gliclazide mr '
#  'LASIX 20 MG OD 11. PREGABLIN 75MG O.D']
# ---------------------------
# Column: PFE, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: PIM, Number of Unique Values: 2
# Unique Values:
# ['YES' 'NO']
# ---------------------------
# Column: DateInOperation, Number of Unique Values: 1713
# Unique Values:
# ['2019-04-29T00:00:00.000000000' '2019-10-17T00:00:00.000000000'
#  '2020-11-27T00:00:00.000000000' '2018-03-06T00:00:00.000000000'
#  '2021-01-13T00:00:00.000000000']
# ---------------------------
# Column: Consultant, Number of Unique Values: 12
# Unique Values:
# ['F' 'A' 'G' 'I' 'K']
# ---------------------------
# Column: Completeness, Number of Unique Values: 2
# Unique Values:
# ['COMPLETE' 'NOT COMPLETE']
# ---------------------------
# Column: Euroscore, Number of Unique Values: 21
# Unique Values:
# [5 9 3 4 1]
# ---------------------------
# Column: EuroscoreII, Number of Unique Values: 991
# Unique Values:
# [2.88 6.16 0.62 1.74 2.03]
# ---------------------------
# Column: BernParsonnet, Number of Unique Values: 40
# Unique Values:
# [10 27  1 12  5]
# ---------------------------
# Column: PTStatusDischarge, Number of Unique Values: 2
# Unique Values:
# ['Alive' 'Dead']
# ---------------------------

# %%
def format_inconsistencies(dataframe):
    for column in dataframe.columns:
        if dataframe[column].apply(type).nunique() > 1:
            print(f"Format inconsistency found in column '{column}':")
        else:
            print(f"No format inconsistencies found in column '{column}'.")

# %%
format_inconsistencies(df)
# Out:
# No format inconsistencies found in column 'ID'.
# No format inconsistencies found in column 'PCCardiacProc'.
# No format inconsistencies found in column 'DOB'.
# No format inconsistencies found in column 'Sex'.
# No format inconsistencies found in column 'RaceName'.
# No format inconsistencies found in column 'ReligionName'.
# No format inconsistencies found in column 'MaritalName'.
# No format inconsistencies found in column 'StateName'.
# No format inconsistencies found in column 'CitizenName'.
# No format inconsistencies found in column 'ResidentialName'.
# Format inconsistency found in column 'Postcode':
# Format inconsistency found in column 'DeceasedDateTime':
# No format inconsistencies found in column 'AdmissionDate'.
# No format inconsistencies found in column 'DischargeDate'.
# No format inconsistencies found in column 'AgeInMonth'.
# No format inconsistencies found in column 'AgeInYear'.
# No format inconsistencies found in column 'GLTypeName'.
# No format inconsistencies found in column 'RA_ValveRepair'.
# No format inconsistencies found in column 'RA_ValveReplacement'.
# No format inconsistencies found in column 'RA_CABG'.
# No format inconsistencies found in column 'RA_OthersSurgery'.
# No format inconsistencies found in column 'RA_NonSurgery'.
# Format inconsistency found in column 'Orthopnea':
# Format inconsistency found in column 'Paroxysmal':
# Format inconsistency found in column 'SymptomStatus':
# No format inconsistencies found in column 'PMHNone'.
# Format inconsistency found in column 'AnginaStatusPresurgery':
# Format inconsistency found in column 'UnstableAngina':
# Format inconsistency found in column 'DyspneaStatusPresurgery':
# No format inconsistencies found in column 'SymptomNone'.
# No format inconsistencies found in column 'ShortofBreath'.
# No format inconsistencies found in column 'ChestPain'.
# No format inconsistencies found in column 'Fatigue'.
# No format inconsistencies found in column 'Palpilation'.
# No format inconsistencies found in column 'sFever'.
# No format inconsistencies found in column 'Cough'.
# No format inconsistencies found in column 'Hemoptysis'.
# No format inconsistencies found in column 'LostofAppetite'.
# No format inconsistencies found in column 'LostofWeight'.
# No format inconsistencies found in column 'LostofConsciousness'.
# Format inconsistency found in column 'SymptomOthers':
# Format inconsistency found in column 'PreviousMI':
# Format inconsistency found in column 'IntervalSurgeryLastMI':
# Format inconsistency found in column 'PreviousPCI':
# Format inconsistency found in column 'FailedInterventionPCI':
# No format inconsistencies found in column 'PreviousCardiacNone'.
# No format inconsistencies found in column 'PreviousCardiacCABG'.
# No format inconsistencies found in column 'PreviousCardiacValve'.
# No format inconsistencies found in column 'PreviousCardiacCongenital'.
# No format inconsistencies found in column 'PreviousCardiacOther'.
# No format inconsistencies found in column 'PreviousCardiacAscAorta'.
# No format inconsistencies found in column 'PreviousCardiacDescAorta'.
# No format inconsistencies found in column 'PreviousCardiacOtherThorac'.
# No format inconsistencies found in column 'PreviousCardiacCarotid'.
# No format inconsistencies found in column 'PreviousCardiacOtherPeri'.
# No format inconsistencies found in column 'OthersPreviousCardiac'.
# No format inconsistencies found in column 'PulmonaryNone'.
# No format inconsistencies found in column 'PulmonaryCOPD'.
# No format inconsistencies found in column 'PulmonaryAsthma'.
# No format inconsistencies found in column 'PulmonaryTB'.
# No format inconsistencies found in column 'PulmonaryLong'.
# No format inconsistencies found in column 'NoHistofNeurological'.
# No format inconsistencies found in column 'TIAorRIND'.
# No format inconsistencies found in column 'CVAwithFullRec'.
# No format inconsistencies found in column 'CVAwithResDef'.
# Format inconsistency found in column 'PoorMobility':
# No format inconsistencies found in column 'GastroenterologyNone'.
# No format inconsistencies found in column 'GastroenterologyGas'.
# No format inconsistencies found in column 'GastroenterologyPUD'.
# No format inconsistencies found in column 'GastroenterologyIBD'.
# No format inconsistencies found in column 'GastroenterologyUN'.
# No format inconsistencies found in column 'GastroenterologyOt'.
# No format inconsistencies found in column 'RFCADNone'.
# Format inconsistency found in column 'RFAcquisitionofDiabetic':
# No format inconsistencies found in column 'DMNot'.
# No format inconsistencies found in column 'DMDiet'.
# No format inconsistencies found in column 'DMOral'.
# No format inconsistencies found in column 'DMInsulin'.
# Format inconsistency found in column 'RFAcquisitionofSmoking':
# Format inconsistency found in column 'RFAcquisitionofHypertension':
# Format inconsistency found in column 'RFAcquisitionofHyperchloles':
# Format inconsistency found in column 'RFAcquisitionofAlcohol':
# No format inconsistencies found in column 'RFAcquisitionofOthers'.
# No format inconsistencies found in column 'AddMedHistRFRenalDis'.
# No format inconsistencies found in column 'NoRenalDisease'.
# No format inconsistencies found in column 'FunctionalTransplant'.
# No format inconsistencies found in column 'CreatineMore2mg'.
# No format inconsistencies found in column 'DialysisAcuteRenal'.
# No format inconsistencies found in column 'ChronicKidneyDisease'.
# No format inconsistencies found in column 'DialysisCRF'.
# No format inconsistencies found in column 'ArteriopathNone'.
# No format inconsistencies found in column 'ArteriopathClaudication'.
# No format inconsistencies found in column 'ArteriopathAmputation'.
# No format inconsistencies found in column 'ArteriopathIntervention'.
# No format inconsistencies found in column 'ArteriopathCarotid'.
# No format inconsistencies found in column 'ArteriopathAortic'.
# Format inconsistency found in column 'PlannedOperation':
# Format inconsistency found in column 'CABGTimeValveSurgery':
# Format inconsistency found in column 'PlannedOperationAorta':
# No format inconsistencies found in column 'SinusRhythm'.
# No format inconsistencies found in column 'AtrialFibrilation'.
# No format inconsistencies found in column 'CompleteHeartBlockPaced'.
# Format inconsistency found in column 'FamilyHistory':
# Format inconsistency found in column 'ActiveEndocarditis':
# Format inconsistency found in column 'Alergic':
# Format inconsistency found in column 'PreopCoros':
# Format inconsistency found in column 'PreopCorosFinding':
# Format inconsistency found in column 'ClinicalPOS':
# Format inconsistency found in column 'PreopVentilation':
# Format inconsistency found in column 'PreOpCardiacMassage':
# Format inconsistency found in column 'PreOpAcuteRenalFailure':
# Format inconsistency found in column 'PreopInotropesIABP':
# No format inconsistencies found in column 'VT_VF'.
# No format inconsistencies found in column 'OtherAbnormalRhythm'.
# Format inconsistency found in column 'urgency':
# Format inconsistency found in column 'PreopCretinine':
# No format inconsistencies found in column 'SurgeryNone'.
# No format inconsistencies found in column 'SurgeryAortic'.
# No format inconsistencies found in column 'SurgeryMitral'.
# No format inconsistencies found in column 'SurgeryTricuspid'.
# No format inconsistencies found in column 'SurgeryPulmonary'.
# Format inconsistency found in column 'PostInfarct':
# Format inconsistency found in column 'LVAneurymectomy':
# Format inconsistency found in column 'RedoOperation':
# Format inconsistency found in column 'MaritalStatus':
# Format inconsistency found in column 'Working':
# Format inconsistency found in column 'CLExtentofCoronary':
# Format inconsistency found in column 'CLLeftmainsteam':
# Format inconsistency found in column 'CLEjectionFraction':
# Format inconsistency found in column 'CLEjectionSystolic':
# Format inconsistency found in column 'PateintHeightcm':
# Format inconsistency found in column 'PatientWeightkg':
# No format inconsistencies found in column 'BMI'.
# No format inconsistencies found in column 'PC_Cramp'.
# No format inconsistencies found in column 'PC_Throb'.
# No format inconsistencies found in column 'PC_Sharp'.
# No format inconsistencies found in column 'PC_Heavy'.
# No format inconsistencies found in column 'PC_Tender'.
# No format inconsistencies found in column 'Freq_Constant'.
# No format inconsistencies found in column 'Freq_Inter'.
# No format inconsistencies found in column 'Agg_Move'.
# No format inconsistencies found in column 'Agg_Position'.
# No format inconsistencies found in column 'Relief_Med'.
# No format inconsistencies found in column 'Relief_NonMed'.
# No format inconsistencies found in column 'MP_ContNormal'.
# No format inconsistencies found in column 'MP_DisPlatlet'.
# No format inconsistencies found in column 'MP_DisOral'.
# No format inconsistencies found in column 'PA_Normal'.
# No format inconsistencies found in column 'PA_Anxious'.
# No format inconsistencies found in column 'PA_Depress'.
# No format inconsistencies found in column 'PA_Illness'.
# Format inconsistency found in column 'PA_IllnessSpecify':
# No format inconsistencies found in column 'PA_Others'.
# Format inconsistency found in column 'PA_OthersSpecify':
# No format inconsistencies found in column 'Invest_Lab'.
# No format inconsistencies found in column 'Invest_Blood'.
# No format inconsistencies found in column 'Invest_BloodCABG'.
# No format inconsistencies found in column 'Invest_BloodRedo'.
# No format inconsistencies found in column 'Invest_BloodAortic'.
# No format inconsistencies found in column 'Invest_BloodOthers'.
# Format inconsistency found in column 'Invest_BloodOthersSpecify':
# No format inconsistencies found in column 'Invest_Chest'.
# No format inconsistencies found in column 'Invest_ECG'.
# No format inconsistencies found in column 'Invest_2DEcho'.
# No format inconsistencies found in column 'Invest_Lung'.
# No format inconsistencies found in column 'Invest_Others'.
# Format inconsistency found in column 'Invest_OthersSpecify':
# No format inconsistencies found in column 'FO_Healthy'.
# No format inconsistencies found in column 'FO_Diabetes'.
# No format inconsistencies found in column 'FO_Dialysis'.
# No format inconsistencies found in column 'FO_Fluid'.
# No format inconsistencies found in column 'FO_FluidVal'.
# No format inconsistencies found in column 'FO_Others'.
# Format inconsistency found in column 'FO_OthersSpecify':
# Format inconsistency found in column 'ProbPatient1':
# Format inconsistency found in column 'ProbPatient2':
# Format inconsistency found in column 'ProbPatient3':
# Format inconsistency found in column 'ProbPatient4':
# Format inconsistency found in column 'CarePlan1':
# Format inconsistency found in column 'CarePlan2':
# Format inconsistency found in column 'CarePlan3':
# Format inconsistency found in column 'CarePlan4':
# Format inconsistency found in column 'CurrMed1':
# Format inconsistency found in column 'CurrMed2':
# Format inconsistency found in column 'CurrMed3':
# Format inconsistency found in column 'CurrMed4':
# Format inconsistency found in column 'CurrMed5':
# Format inconsistency found in column 'CurrMed6':
# Format inconsistency found in column 'CurrMed7':
# Format inconsistency found in column 'CurrMed8':
# Format inconsistency found in column 'CurrMed9':
# Format inconsistency found in column 'CurrMed10':
# No format inconsistencies found in column 'PFE'.
# No format inconsistencies found in column 'PIM'.
# No format inconsistencies found in column 'DateInOperation'.
# No format inconsistencies found in column 'Consultant'.
# No format inconsistencies found in column 'Completeness'.
# No format inconsistencies found in column 'Euroscore'.
# No format inconsistencies found in column 'EuroscoreII'.
# No format inconsistencies found in column 'BernParsonnet'.
# No format inconsistencies found in column 'PTStatusDischarge'.

# %%
def missing_values(dataframe):
    missing_columns = dataframe.columns[dataframe.isnull().any()]

    if len(missing_columns) == 0:
        print("No missing values in DataFrame")
        return

    total_columns_with_missing = len(missing_columns)
    print(f"Total columns with missing values: {total_columns_with_missing}")

    for column in missing_columns:
        missing_values_count = dataframe[column].isnull().sum()
        total_values = len(dataframe[column])
        missing_percentage = (missing_values_count / total_values) * 100

        print(f"Column: {column}, Missing Values: {missing_values_count}, Percentage: {round(missing_percentage, 2)}%")

# %%
missing_values(df)
# Out:
# Total columns with missing values: 70
# Column: Postcode, Missing Values: 1, Percentage: 0.01%
# Column: Orthopnea, Missing Values: 70, Percentage: 0.65%
# Column: Paroxysmal, Missing Values: 82, Percentage: 0.76%
# Column: SymptomStatus, Missing Values: 380, Percentage: 3.54%
# Column: AnginaStatusPresurgery, Missing Values: 39, Percentage: 0.36%
# Column: UnstableAngina, Missing Values: 814, Percentage: 7.58%
# Column: DyspneaStatusPresurgery, Missing Values: 52, Percentage: 0.48%
# Column: SymptomOthers, Missing Values: 10543, Percentage: 98.23%
# Column: PreviousMI, Missing Values: 386, Percentage: 3.6%
# Column: IntervalSurgeryLastMI, Missing Values: 317, Percentage: 2.95%
# Column: PreviousPCI, Missing Values: 612, Percentage: 5.7%
# Column: FailedInterventionPCI, Missing Values: 2113, Percentage: 19.69%
# Column: PoorMobility, Missing Values: 381, Percentage: 3.55%
# Column: RFAcquisitionofDiabetic, Missing Values: 4, Percentage: 0.04%
# Column: RFAcquisitionofSmoking, Missing Values: 401, Percentage: 3.74%
# Column: RFAcquisitionofHypertension, Missing Values: 10, Percentage: 0.09%
# Column: RFAcquisitionofHyperchloles, Missing Values: 56, Percentage: 0.52%
# Column: RFAcquisitionofAlcohol, Missing Values: 967, Percentage: 9.01%
# Column: RFAcquisitionofOthers, Missing Values: 10733, Percentage: 100.0%
# Column: AddMedHistRFRenalDis, Missing Values: 10733, Percentage: 100.0%
# Column: PlannedOperation, Missing Values: 2462, Percentage: 22.94%
# Column: CABGTimeValveSurgery, Missing Values: 411, Percentage: 3.83%
# Column: PlannedOperationAorta, Missing Values: 2375, Percentage: 22.13%
# Column: FamilyHistory, Missing Values: 1133, Percentage: 10.56%
# Column: ActiveEndocarditis, Missing Values: 374, Percentage: 3.48%
# Column: Alergic, Missing Values: 406, Percentage: 3.78%
# Column: PreopCoros, Missing Values: 725, Percentage: 6.75%
# Column: PreopCorosFinding, Missing Values: 992, Percentage: 9.24%
# Column: ClinicalPOS, Missing Values: 549, Percentage: 5.12%
# Column: PreopVentilation, Missing Values: 68, Percentage: 0.63%
# Column: PreOpCardiacMassage, Missing Values: 62, Percentage: 0.58%
# Column: PreOpAcuteRenalFailure, Missing Values: 66, Percentage: 0.61%
# Column: PreopInotropesIABP, Missing Values: 60, Percentage: 0.56%
# Column: urgency, Missing Values: 1, Percentage: 0.01%
# Column: PreopCretinine, Missing Values: 776, Percentage: 7.23%
# Column: PostInfarct, Missing Values: 470, Percentage: 4.38%
# Column: LVAneurymectomy, Missing Values: 508, Percentage: 4.73%
# Column: RedoOperation, Missing Values: 287, Percentage: 2.67%
# Column: MaritalStatus, Missing Values: 1127, Percentage: 10.5%
# Column: Working, Missing Values: 1468, Percentage: 13.68%
# Column: CLExtentofCoronary, Missing Values: 1001, Percentage: 9.33%
# Column: CLLeftmainsteam, Missing Values: 2572, Percentage: 23.96%
# Column: CLEjectionFraction, Missing Values: 363, Percentage: 3.38%
# Column: CLEjectionSystolic, Missing Values: 380, Percentage: 3.54%
# Column: PateintHeightcm, Missing Values: 10, Percentage: 0.09%
# Column: PatientWeightkg, Missing Values: 729, Percentage: 6.79%
# Column: BMI, Missing Values: 736, Percentage: 6.86%
# Column: PA_IllnessSpecify, Missing Values: 10729, Percentage: 99.96%
# Column: PA_OthersSpecify, Missing Values: 10726, Percentage: 99.93%
# Column: Invest_BloodOthersSpecify, Missing Values: 10608, Percentage: 98.84%
# Column: Invest_OthersSpecify, Missing Values: 10543, Percentage: 98.23%
# Column: FO_OthersSpecify, Missing Values: 10725, Percentage: 99.93%
# Column: ProbPatient1, Missing Values: 1490, Percentage: 13.88%
# Column: ProbPatient2, Missing Values: 4058, Percentage: 37.81%
# Column: ProbPatient3, Missing Values: 6497, Percentage: 60.53%
# Column: ProbPatient4, Missing Values: 8941, Percentage: 83.3%
# Column: CarePlan1, Missing Values: 1577, Percentage: 14.69%
# Column: CarePlan2, Missing Values: 7888, Percentage: 73.49%
# Column: CarePlan3, Missing Values: 10403, Percentage: 96.93%
# Column: CarePlan4, Missing Values: 10671, Percentage: 99.42%
# Column: CurrMed1, Missing Values: 1534, Percentage: 14.29%
# Column: CurrMed2, Missing Values: 10207, Percentage: 95.1%
# Column: CurrMed3, Missing Values: 10593, Percentage: 98.7%
# Column: CurrMed4, Missing Values: 10606, Percentage: 98.82%
# Column: CurrMed5, Missing Values: 10609, Percentage: 98.84%
# Column: CurrMed6, Missing Values: 10641, Percentage: 99.14%
# Column: CurrMed7, Missing Values: 10673, Percentage: 99.44%
# Column: CurrMed8, Missing Values: 10701, Percentage: 99.7%
# Column: CurrMed9, Missing Values: 10713, Percentage: 99.81%
# Column: CurrMed10, Missing Values: 10721, Percentage: 99.89%

# %% [markdown]
# # 3.0 Data Cleaning

# %%
def drop_columns(dataframe, threshold):
    total_columns = len(dataframe.columns)
    threshold_count = int(threshold * len(dataframe))
    
    columns_to_drop = dataframe.columns[dataframe.isnull().sum() > threshold_count]
    
    dataframe_dropped = dataframe.drop(columns=columns_to_drop)
    
    print("Columns Dropped:")
    print(columns_to_drop)
    
    return dataframe_dropped

# %%
threshold_value = 0.5
df = drop_columns(df, threshold_value)
# Out:
# Columns Dropped:
# Index(['SymptomOthers', 'RFAcquisitionofOthers', 'AddMedHistRFRenalDis',
#        'PA_IllnessSpecify', 'PA_OthersSpecify', 'Invest_BloodOthersSpecify',
#        'Invest_OthersSpecify', 'FO_OthersSpecify', 'ProbPatient3',
#        'ProbPatient4', 'CarePlan2', 'CarePlan3', 'CarePlan4', 'CurrMed2',
#        'CurrMed3', 'CurrMed4', 'CurrMed5', 'CurrMed6', 'CurrMed7', 'CurrMed8',
#        'CurrMed9', 'CurrMed10'],
#       dtype='object')

# %%
missing_values(df)
# Out:
# Total columns with missing values: 48
# Column: Postcode, Missing Values: 1, Percentage: 0.01%
# Column: Orthopnea, Missing Values: 70, Percentage: 0.65%
# Column: Paroxysmal, Missing Values: 82, Percentage: 0.76%
# Column: SymptomStatus, Missing Values: 380, Percentage: 3.54%
# Column: AnginaStatusPresurgery, Missing Values: 39, Percentage: 0.36%
# Column: UnstableAngina, Missing Values: 814, Percentage: 7.58%
# Column: DyspneaStatusPresurgery, Missing Values: 52, Percentage: 0.48%
# Column: PreviousMI, Missing Values: 386, Percentage: 3.6%
# Column: IntervalSurgeryLastMI, Missing Values: 317, Percentage: 2.95%
# Column: PreviousPCI, Missing Values: 612, Percentage: 5.7%
# Column: FailedInterventionPCI, Missing Values: 2113, Percentage: 19.69%
# Column: PoorMobility, Missing Values: 381, Percentage: 3.55%
# Column: RFAcquisitionofDiabetic, Missing Values: 4, Percentage: 0.04%
# Column: RFAcquisitionofSmoking, Missing Values: 401, Percentage: 3.74%
# Column: RFAcquisitionofHypertension, Missing Values: 10, Percentage: 0.09%
# Column: RFAcquisitionofHyperchloles, Missing Values: 56, Percentage: 0.52%
# Column: RFAcquisitionofAlcohol, Missing Values: 967, Percentage: 9.01%
# Column: PlannedOperation, Missing Values: 2462, Percentage: 22.94%
# Column: CABGTimeValveSurgery, Missing Values: 411, Percentage: 3.83%
# Column: PlannedOperationAorta, Missing Values: 2375, Percentage: 22.13%
# Column: FamilyHistory, Missing Values: 1133, Percentage: 10.56%
# Column: ActiveEndocarditis, Missing Values: 374, Percentage: 3.48%
# Column: Alergic, Missing Values: 406, Percentage: 3.78%
# Column: PreopCoros, Missing Values: 725, Percentage: 6.75%
# Column: PreopCorosFinding, Missing Values: 992, Percentage: 9.24%
# Column: ClinicalPOS, Missing Values: 549, Percentage: 5.12%
# Column: PreopVentilation, Missing Values: 68, Percentage: 0.63%
# Column: PreOpCardiacMassage, Missing Values: 62, Percentage: 0.58%
# Column: PreOpAcuteRenalFailure, Missing Values: 66, Percentage: 0.61%
# Column: PreopInotropesIABP, Missing Values: 60, Percentage: 0.56%
# Column: urgency, Missing Values: 1, Percentage: 0.01%
# Column: PreopCretinine, Missing Values: 776, Percentage: 7.23%
# Column: PostInfarct, Missing Values: 470, Percentage: 4.38%
# Column: LVAneurymectomy, Missing Values: 508, Percentage: 4.73%
# Column: RedoOperation, Missing Values: 287, Percentage: 2.67%
# Column: MaritalStatus, Missing Values: 1127, Percentage: 10.5%
# Column: Working, Missing Values: 1468, Percentage: 13.68%
# Column: CLExtentofCoronary, Missing Values: 1001, Percentage: 9.33%
# Column: CLLeftmainsteam, Missing Values: 2572, Percentage: 23.96%
# Column: CLEjectionFraction, Missing Values: 363, Percentage: 3.38%
# Column: CLEjectionSystolic, Missing Values: 380, Percentage: 3.54%
# Column: PateintHeightcm, Missing Values: 10, Percentage: 0.09%
# Column: PatientWeightkg, Missing Values: 729, Percentage: 6.79%
# Column: BMI, Missing Values: 736, Percentage: 6.86%
# Column: ProbPatient1, Missing Values: 1490, Percentage: 13.88%
# Column: ProbPatient2, Missing Values: 4058, Percentage: 37.81%
# Column: CarePlan1, Missing Values: 1577, Percentage: 14.69%
# Column: CurrMed1, Missing Values: 1534, Percentage: 14.29%

# %%
columns_to_convert = ['PreopCretinine','CLEjectionFraction','PateintHeightcm','PatientWeightkg']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors = 'coerce')

# %%
def impute_with_mean(dataframe, columns):
  
    column_means = dataframe[columns].mean()
    dataframe_imputed = dataframe.copy()
    
    for column in columns:
        dataframe_imputed[column].fillna(column_means[column], inplace=True)
    
    return dataframe_imputed

# %%
columns_to_impute = ['BMI','PreopCretinine','CLEjectionFraction','PateintHeightcm','PatientWeightkg']  
df = impute_with_mean(df, columns_to_impute)

# %%
df.fillna('UNKNOWN', inplace=True)

# %%
df.replace('Unknown', 'UNKNOWN', inplace=True)

# %% [markdown]
# # 4.0 Data Transformation

# %%
df['LOS'] = (df['DischargeDate'] - df['AdmissionDate']).dt.days
df['LOS'] = df['LOS'].astype(int)
df.head()
# Out:
# C:\Users\afiq_\AppData\Local\Temp\ipykernel_2860\1370321919.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['LOS'] = (df['DischargeDate'] - df['AdmissionDate']).dt.days
#    ID    PCCardiacProc        DOB     Sex RaceName ReligionName MaritalName  \
# 0   1      Valve alone 1966-02-21    MALE    Malay        Islam     Married
# 1   2  Valve and Other 1942-05-08  FEMALE    Malay        Islam     Married
# 2   3            other 1990-06-17  FEMALE    Malay        Islam      Single
# 3   4      Valve alone 1976-11-27    MALE    Malay        Islam      Single
# 4   5      Valve alone 1989-01-03  FEMALE  Chinese     Buddhism     Married
#
#              StateName CitizenName ResidentialName  ...  PFE  PIM  \
# 0             Selangor    Malaysia       Malaysian  ...  YES  YES
# 1      Negeri Sembilan    Malaysia       Malaysian  ...  YES  YES
# 2               Perlis    Malaysia       Malaysian  ...   NO   NO
# 3                Perak    Malaysia       Malaysian  ...   NO   NO
# 4  Wilayah Persekutuan    Malaysia       Malaysian  ...  YES   NO
#
#   DateInOperation Consultant  Completeness  Euroscore EuroscoreII  \
# 0      2019-04-29          F      COMPLETE          5        2.88
# 1      2019-10-17          A      COMPLETE          9        6.16
# 2      2020-11-27          G      COMPLETE          3        0.62
# 3      2018-03-06          F      COMPLETE          5        1.74
# 4      2021-01-13          I      COMPLETE          3        0.62
#
#   BernParsonnet PTStatusDischarge LOS
# 0            10             Alive  22
# 1            27             Alive  17
# 2             1             Alive  23
# 3            12             Alive  10
# 4             1             Alive   9
#
# [5 rows x 180 columns]

# %%
def categorize_bmi(bmi):
    if bmi < 0:
        return 'Not Recorded'
    elif bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 25:
        return 'Normal weight'
    elif 25 <= bmi < 30:
        return 'Overweight'
    else:
        return 'Obese'

# %%
df['BMI'] = df['BMI'].apply(categorize_bmi)
df['BMI'].head()
# Out:
# 0       Overweight
# 1       Overweight
# 2    Normal weight
# 3    Normal weight
# 4      Underweight
# Name: BMI, dtype: object

# %%
def categorize_euroscore2(euroscore2, completeness):
    if completeness == 'COMPLETE':
        if euroscore2 <= 0.80:
            return 'Low risk'
        elif 0.81 <= euroscore2 <= 1.22:
            return 'Medium risk'
        elif 1.23 <= euroscore2 <= 2.02:
            return "Medium-high risk"
        elif 2.03 <= euroscore2 <= 4.11:
            return "High risk"
        else:
            return "Very high risk"
    elif completeness == 'NOT COMPLETE':
        return "Incomplete"
    else:
        return "Completeness value not recognized"

# %%
df['Risk Group'] = df.apply(lambda row: categorize_euroscore2(row['EuroscoreII'], row['Completeness']), axis=1)

# %%
df['Risk Group'].head()
# Out:
# 0           High risk
# 1      Very high risk
# 2            Low risk
# 3    Medium-high risk
# 4            Low risk
# Name: Risk Group, dtype: object

# %%
import numpy as np

# %%
# Define conditions and categories
conditions = [
    df['LOS'] <= 14,
    (df['LOS'] > 14) & (df['LOS'] <= 30),
    df['LOS'] >= 31
]
categories = ["Short(0-14 days)", "Medium(15-30 days)", "Long(>30 days)"]

# Apply conditions to create new column
df['Category LOS'] = np.select(conditions, categories, default='Unknown')

# %%
# Define conditions and categories
conditions = [
    df['AgeInYear'] <= 11,
    (df['AgeInYear'] > 11) & (df['AgeInYear'] <= 17),
    (df['AgeInYear'] > 17) & (df['AgeInYear'] <= 40),
    (df['AgeInYear'] > 40) & (df['AgeInYear'] <= 59),
    df['AgeInYear'] >= 60
]
categories = [
    "Child(Below 11)",
    "Adolescent(12-17)",
    "Early Adulthood(18-40)",
    "Middle Adulthood(41-59)",
    "Elderly (Above 60)"
]

# Apply conditions to create new column
df['Age Group'] = np.select(conditions, categories, default='Unknown')

# %%
def categorize_creatine(creatine):
    if creatine < 74.3:
        return 'Low'
    elif 74.3 <= creatine < 107:
        return 'Normal'
    else:
        return 'High'

# %%
df['PreopCretinine'] = df['PreopCretinine'].apply(categorize_creatine)

# %%
def categorize_gltype(gltype):
    if 'GOVT' in gltype or gltype in ["Govt Referred Patient", "Govt Referred Pt", "Govt Sponsored Patient"]:
        return 'Government(GOVT)'
    elif 'STAT' in gltype:
        return "State(STAT)"
    elif 'STGV' in gltype:
        return "State Government(STGV)"
    elif 'LOCA' in gltype:
        return "Local Authority(LOCA)"
    elif 'MOH' in gltype:
        return "Ministry of Health(MOH)"
    elif 'PENS' in gltype or 'Pensioner' in gltype:
        return 'Pensioner'
    elif gltype == "Private Paying Ind.":
        return 'Private Paying Individual'
    elif gltype == "Insurance":
        return 'Insurance'
    elif gltype == "MCO/ TPA":
        return 'Managed Care Organization(MCO)/ Third-Party Administrator(TPA)'
    elif gltype == "Company":
        return 'Company'
    else:
        return 'Other'

# %%
# Apply the function to create a new MainType column
df['GLCategories'] = df['GLTypeName'].apply(categorize_gltype)

# %%
df['GLCategories'].value_counts()
# Out:
# Government(GOVT)                                                  3600
# Pensioner                                                         2161
# Private Paying Individual                                         1554
# Insurance                                                         1091
# Managed Care Organization(MCO)/ Third-Party Administrator(TPA)     836
# State(STAT)                                                        436
# Ministry of Health(MOH)                                            342
# State Government(STGV)                                             201
# Local Authority(LOCA)                                              180
# Other                                                              173
# Company                                                            159
# Name: GLCategories, dtype: int64

# %% [markdown]
# # 5.0 Data Verification and Validation

# %%
missing_values(df)
# Out:
# No missing values in DataFrame

# %%
format_inconsistencies(df)
# Out:
# No format inconsistencies found in column 'ID'.
# No format inconsistencies found in column 'PCCardiacProc'.
# No format inconsistencies found in column 'DOB'.
# No format inconsistencies found in column 'Sex'.
# No format inconsistencies found in column 'RaceName'.
# No format inconsistencies found in column 'ReligionName'.
# No format inconsistencies found in column 'MaritalName'.
# No format inconsistencies found in column 'StateName'.
# No format inconsistencies found in column 'CitizenName'.
# No format inconsistencies found in column 'ResidentialName'.
# Format inconsistency found in column 'Postcode':
# Format inconsistency found in column 'DeceasedDateTime':
# No format inconsistencies found in column 'AdmissionDate'.
# No format inconsistencies found in column 'DischargeDate'.
# No format inconsistencies found in column 'AgeInMonth'.
# No format inconsistencies found in column 'AgeInYear'.
# No format inconsistencies found in column 'GLTypeName'.
# No format inconsistencies found in column 'RA_ValveRepair'.
# No format inconsistencies found in column 'RA_ValveReplacement'.
# No format inconsistencies found in column 'RA_CABG'.
# No format inconsistencies found in column 'RA_OthersSurgery'.
# No format inconsistencies found in column 'RA_NonSurgery'.
# No format inconsistencies found in column 'Orthopnea'.
# No format inconsistencies found in column 'Paroxysmal'.
# No format inconsistencies found in column 'SymptomStatus'.
# No format inconsistencies found in column 'PMHNone'.
# No format inconsistencies found in column 'AnginaStatusPresurgery'.
# No format inconsistencies found in column 'UnstableAngina'.
# No format inconsistencies found in column 'DyspneaStatusPresurgery'.
# No format inconsistencies found in column 'SymptomNone'.
# No format inconsistencies found in column 'ShortofBreath'.
# No format inconsistencies found in column 'ChestPain'.
# No format inconsistencies found in column 'Fatigue'.
# No format inconsistencies found in column 'Palpilation'.
# No format inconsistencies found in column 'sFever'.
# No format inconsistencies found in column 'Cough'.
# No format inconsistencies found in column 'Hemoptysis'.
# No format inconsistencies found in column 'LostofAppetite'.
# No format inconsistencies found in column 'LostofWeight'.
# No format inconsistencies found in column 'LostofConsciousness'.
# No format inconsistencies found in column 'PreviousMI'.
# No format inconsistencies found in column 'IntervalSurgeryLastMI'.
# No format inconsistencies found in column 'PreviousPCI'.
# No format inconsistencies found in column 'FailedInterventionPCI'.
# No format inconsistencies found in column 'PreviousCardiacNone'.
# No format inconsistencies found in column 'PreviousCardiacCABG'.
# No format inconsistencies found in column 'PreviousCardiacValve'.
# No format inconsistencies found in column 'PreviousCardiacCongenital'.
# No format inconsistencies found in column 'PreviousCardiacOther'.
# No format inconsistencies found in column 'PreviousCardiacAscAorta'.
# No format inconsistencies found in column 'PreviousCardiacDescAorta'.
# No format inconsistencies found in column 'PreviousCardiacOtherThorac'.
# No format inconsistencies found in column 'PreviousCardiacCarotid'.
# No format inconsistencies found in column 'PreviousCardiacOtherPeri'.
# No format inconsistencies found in column 'OthersPreviousCardiac'.
# No format inconsistencies found in column 'PulmonaryNone'.
# No format inconsistencies found in column 'PulmonaryCOPD'.
# No format inconsistencies found in column 'PulmonaryAsthma'.
# No format inconsistencies found in column 'PulmonaryTB'.
# No format inconsistencies found in column 'PulmonaryLong'.
# No format inconsistencies found in column 'NoHistofNeurological'.
# No format inconsistencies found in column 'TIAorRIND'.
# No format inconsistencies found in column 'CVAwithFullRec'.
# No format inconsistencies found in column 'CVAwithResDef'.
# No format inconsistencies found in column 'PoorMobility'.
# No format inconsistencies found in column 'GastroenterologyNone'.
# No format inconsistencies found in column 'GastroenterologyGas'.
# No format inconsistencies found in column 'GastroenterologyPUD'.
# No format inconsistencies found in column 'GastroenterologyIBD'.
# No format inconsistencies found in column 'GastroenterologyUN'.
# No format inconsistencies found in column 'GastroenterologyOt'.
# No format inconsistencies found in column 'RFCADNone'.
# No format inconsistencies found in column 'RFAcquisitionofDiabetic'.
# No format inconsistencies found in column 'DMNot'.
# No format inconsistencies found in column 'DMDiet'.
# No format inconsistencies found in column 'DMOral'.
# No format inconsistencies found in column 'DMInsulin'.
# No format inconsistencies found in column 'RFAcquisitionofSmoking'.
# No format inconsistencies found in column 'RFAcquisitionofHypertension'.
# No format inconsistencies found in column 'RFAcquisitionofHyperchloles'.
# No format inconsistencies found in column 'RFAcquisitionofAlcohol'.
# No format inconsistencies found in column 'NoRenalDisease'.
# No format inconsistencies found in column 'FunctionalTransplant'.
# No format inconsistencies found in column 'CreatineMore2mg'.
# No format inconsistencies found in column 'DialysisAcuteRenal'.
# No format inconsistencies found in column 'ChronicKidneyDisease'.
# No format inconsistencies found in column 'DialysisCRF'.
# No format inconsistencies found in column 'ArteriopathNone'.
# No format inconsistencies found in column 'ArteriopathClaudication'.
# No format inconsistencies found in column 'ArteriopathAmputation'.
# No format inconsistencies found in column 'ArteriopathIntervention'.
# No format inconsistencies found in column 'ArteriopathCarotid'.
# No format inconsistencies found in column 'ArteriopathAortic'.
# No format inconsistencies found in column 'PlannedOperation'.
# No format inconsistencies found in column 'CABGTimeValveSurgery'.
# No format inconsistencies found in column 'PlannedOperationAorta'.
# No format inconsistencies found in column 'SinusRhythm'.
# No format inconsistencies found in column 'AtrialFibrilation'.
# No format inconsistencies found in column 'CompleteHeartBlockPaced'.
# No format inconsistencies found in column 'FamilyHistory'.
# No format inconsistencies found in column 'ActiveEndocarditis'.
# No format inconsistencies found in column 'Alergic'.
# No format inconsistencies found in column 'PreopCoros'.
# No format inconsistencies found in column 'PreopCorosFinding'.
# No format inconsistencies found in column 'ClinicalPOS'.
# No format inconsistencies found in column 'PreopVentilation'.
# No format inconsistencies found in column 'PreOpCardiacMassage'.
# No format inconsistencies found in column 'PreOpAcuteRenalFailure'.
# No format inconsistencies found in column 'PreopInotropesIABP'.
# No format inconsistencies found in column 'VT_VF'.
# No format inconsistencies found in column 'OtherAbnormalRhythm'.
# No format inconsistencies found in column 'urgency'.
# No format inconsistencies found in column 'PreopCretinine'.
# No format inconsistencies found in column 'SurgeryNone'.
# No format inconsistencies found in column 'SurgeryAortic'.
# No format inconsistencies found in column 'SurgeryMitral'.
# No format inconsistencies found in column 'SurgeryTricuspid'.
# No format inconsistencies found in column 'SurgeryPulmonary'.
# No format inconsistencies found in column 'PostInfarct'.
# No format inconsistencies found in column 'LVAneurymectomy'.
# No format inconsistencies found in column 'RedoOperation'.
# No format inconsistencies found in column 'MaritalStatus'.
# No format inconsistencies found in column 'Working'.
# No format inconsistencies found in column 'CLExtentofCoronary'.
# No format inconsistencies found in column 'CLLeftmainsteam'.
# No format inconsistencies found in column 'CLEjectionFraction'.
# No format inconsistencies found in column 'CLEjectionSystolic'.
# No format inconsistencies found in column 'PateintHeightcm'.
# No format inconsistencies found in column 'PatientWeightkg'.
# No format inconsistencies found in column 'BMI'.
# No format inconsistencies found in column 'PC_Cramp'.
# No format inconsistencies found in column 'PC_Throb'.
# No format inconsistencies found in column 'PC_Sharp'.
# No format inconsistencies found in column 'PC_Heavy'.
# No format inconsistencies found in column 'PC_Tender'.
# No format inconsistencies found in column 'Freq_Constant'.
# No format inconsistencies found in column 'Freq_Inter'.
# No format inconsistencies found in column 'Agg_Move'.
# No format inconsistencies found in column 'Agg_Position'.
# No format inconsistencies found in column 'Relief_Med'.
# No format inconsistencies found in column 'Relief_NonMed'.
# No format inconsistencies found in column 'MP_ContNormal'.
# No format inconsistencies found in column 'MP_DisPlatlet'.
# No format inconsistencies found in column 'MP_DisOral'.
# No format inconsistencies found in column 'PA_Normal'.
# No format inconsistencies found in column 'PA_Anxious'.
# No format inconsistencies found in column 'PA_Depress'.
# No format inconsistencies found in column 'PA_Illness'.
# No format inconsistencies found in column 'PA_Others'.
# No format inconsistencies found in column 'Invest_Lab'.
# No format inconsistencies found in column 'Invest_Blood'.
# No format inconsistencies found in column 'Invest_BloodCABG'.
# No format inconsistencies found in column 'Invest_BloodRedo'.
# No format inconsistencies found in column 'Invest_BloodAortic'.
# No format inconsistencies found in column 'Invest_BloodOthers'.
# No format inconsistencies found in column 'Invest_Chest'.
# No format inconsistencies found in column 'Invest_ECG'.
# No format inconsistencies found in column 'Invest_2DEcho'.
# No format inconsistencies found in column 'Invest_Lung'.
# No format inconsistencies found in column 'Invest_Others'.
# No format inconsistencies found in column 'FO_Healthy'.
# No format inconsistencies found in column 'FO_Diabetes'.
# No format inconsistencies found in column 'FO_Dialysis'.
# No format inconsistencies found in column 'FO_Fluid'.
# No format inconsistencies found in column 'FO_FluidVal'.
# No format inconsistencies found in column 'FO_Others'.
# No format inconsistencies found in column 'ProbPatient1'.
# No format inconsistencies found in column 'ProbPatient2'.
# No format inconsistencies found in column 'CarePlan1'.
# No format inconsistencies found in column 'CurrMed1'.
# No format inconsistencies found in column 'PFE'.
# No format inconsistencies found in column 'PIM'.
# No format inconsistencies found in column 'DateInOperation'.
# No format inconsistencies found in column 'Consultant'.
# No format inconsistencies found in column 'Completeness'.
# No format inconsistencies found in column 'Euroscore'.
# No format inconsistencies found in column 'EuroscoreII'.
# No format inconsistencies found in column 'BernParsonnet'.
# No format inconsistencies found in column 'PTStatusDischarge'.
# No format inconsistencies found in column 'LOS'.
# No format inconsistencies found in column 'Risk Group'.
# No format inconsistencies found in column 'Category LOS'.
# No format inconsistencies found in column 'Age Group'.
# No format inconsistencies found in column 'GLCategories'.

# %%
df.shape
# Out:
# (10733, 184)

# %%
cleaned_df_path = 'Main Cleaned Healthcare Dataset.csv'
df.to_csv(cleaned_df_path, index=False)

# %% [markdown]
# # 6.0 Dashboard Data

# %%
surgery_df = df[["ID", "Sex", "RaceName", "ReligionName", "CitizenName", "AdmissionDate", "DischargeDate", "AgeInYear","GLTypeName","PCCardiacProc","AnginaStatusPresurgery", 
                 "UnstableAngina", "DyspneaStatusPresurgery", "PreviousMI", "IntervalSurgeryLastMI", "PreviousCardiacNone", "PreviousCardiacCABG", 
                 "PreviousCardiacValve", "PreviousCardiacCongenital", "PreviousCardiacOther", "PreviousCardiacAscAorta", "PreviousCardiacDescAorta", 
                 "PreviousCardiacOtherThorac", "PreviousCardiacCarotid", "PreviousCardiacOtherPeri", "OthersPreviousCardiac", "PulmonaryNone", 
                 "PulmonaryCOPD", "PulmonaryAsthma", "PulmonaryTB", "PulmonaryLong", "NoHistofNeurological", "TIAorRIND", "CVAwithFullRec", 
                 "CVAwithResDef", "PoorMobility", "RFAcquisitionofDiabetic", "DMNot", "DMDiet", "DMOral", "DMInsulin", "RFAcquisitionofSmoking",
                 "RFAcquisitionofHypertension", "NoRenalDisease", "ChronicKidneyDisease", "ArteriopathNone", "ArteriopathClaudication", 
                 "ArteriopathAmputation", "ArteriopathIntervention", "ArteriopathCarotid", "ArteriopathAortic", "PlannedOperation", 
                 "PlannedOperationAorta", "ActiveEndocarditis", "ClinicalPOS", "PreopVentilation", "PreOpCardiacMassage", 
                 "PreOpAcuteRenalFailure", "PreopInotropesIABP", "VT_VF", "urgency", "PreopCretinine", "PostInfarct", "RedoOperation", "MaritalStatus", 
                 "Working", "CLEjectionFraction", "CLEjectionSystolic", "BMI", "DateInOperation", "Consultant", "Completeness", "EuroscoreII", 
                 "PTStatusDischarge", "LOS", "Risk Group", "Category LOS", "Age Group","GLCategories"]]

# %%
cleaned_df = 'Cleaned Healthcare Dataset.csv'
surgery_df.to_csv(cleaned_df, index=False)
